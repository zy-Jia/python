# %%
import pandas as pd

# %%
kc_data = pd.read_csv('kc_house_data.csv', keep_default_na=False).fillna(0)
kc_data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
kc_data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
kc_data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
kc_data.fillna(0)
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
kc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  object
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt
corr = kc_data.corr()
print(type(corr))
# print(corr)
plt.figure(figsize=(25,10))
sns.heatmap(corr)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <AxesSubplot:>

# %%
# categorical_columns = []

# for i in kc_data.columns:
#   unique_values = len(pd.unique(kc_data[i])) 
#   if unique_values < 90:
#     categorical_columns.append(i)
# categorical_columns

# %%
# split categorical columns and numerical columns
categorical_mask = (kc_data.dtypes == object)
categorical_cols = kc_data.columns[categorical_mask].tolist()
numeric_cols = kc_data.columns[~categorical_mask].tolist()
numeric_cols.remove('id')
numeric_cols.remove('price')
print(f'categorical_cols are {categorical_cols}' )
print(f'numeric_cols are {numeric_cols}' )
X = kc_data[numeric_cols]
X.head()
# X = kc_data
# X = X.drop(["yr_built", "id", "price", "date"], axis = 1)
# Out:
# categorical_cols are ['date', 'yr_built']
# numeric_cols are ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 0          3      7        1180              0             0    98178
# 1          3      7        2170            400          1991    98125
# ...

# %%
y = kc_data[['price']]
y
# Out:
#           price
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# ...         ...
# 21608  360000.0
# 21609  400000.0
# 21610  402101.0
# 21611  400000.0
# 21612  325000.0
#
# [21613 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from ML_Package.MultivarateRegression import MultivarateRegression
mr = MultivarateRegression()

# %%
mr.fit_normal(X_train, y_train)
# Out:
# MultivarateRegression()

# %%
y_pred = mr.predict(X_test)
y_pred
# Out:
# array([[-1101540.26321071],
#        [ -561521.02637074],
#        [  142552.6732696 ],
#        ...,
#        [  478719.97202106],
#        [  143362.51081947],
#        [-1663628.32259963]])

# %%
from ML_Package.metrics import mse

# %%
mse(y_pred, y_test)
# Out:
# price    9.757850e+11
# dtype: float64

# %%
mr.score(X_test, y_test)
# Out:
# price   -6.602293
# dtype: float64
